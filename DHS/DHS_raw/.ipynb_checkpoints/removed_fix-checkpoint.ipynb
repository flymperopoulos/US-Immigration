# %%
import pandas as pd

# %%
remov = pd.read_excel('removed1892-13.xls')
remov.set_index('Year', 1, inplace=True)
del remov.index.name
remov.to_csv('../removed.csv')

# %%
remov.head()
# Out:
#       Removals  Returns
# 1892      2801      NaN
# 1893      1630      NaN
# 1894      1806      NaN
# 1895      2596      NaN
# 1896      3037      NaN

# %%
remov99 = pd.read_excel('removed_nat99-08.xls')
remov99 = remov99.transpose()
remov99.head()
# Out:
#              1999      1999          1999    2000      2000          2000  \
# Type        Total  Criminal  Non-Criminal   Total  Criminal  Non-Criminal
# Total      183114     71188        111926  188467     73065        115402
# Africa       1555       620           935    1593       623           970
# Asia         3334      1015          2319    3725      1021          2704
# Caribbean    6534      4613          1921    6706      4609          2097
#
#              2001      2001          2001    2002      ...               2005  \
# Type        Total  Criminal  Non-Criminal   Total      ...       Non-Criminal
# Total      189026     73545        115481  165168      ...             154706
# Africa       1532       585           947    2110      ...               1602
# Asia         3748      1032          2716    5111      ...               4734
# Caribbean    7341      4368          2973    7111      ...               2918
#
# ...

# %%
remov93 = pd.read_excel('removed_nat93-03.xls')
remov93 = remov93

criminal, non, total = remov93.groupby('Type')
criminal = pd.DataFrame(criminal[1])
criminal
# Out:
#           Type  Total  Europe  Albania  Andorra  Armenia  Austria  Azerbaijan  \
# 1993  Criminal  29457     334      NaN        0        0      NaN           0
# 1994  Criminal  32510     384        4        0      NaN      NaN           0
# 1995  Criminal  33842     402        4        0      NaN      NaN           0
# 1996  Criminal  38015     458        5        0      NaN      NaN         NaN
# 1997  Criminal  53214     544        4        0      NaN      NaN           0
# 1998  Criminal  60965     715        6        0        4        4           0
#
#       Belarus  Belgium           ...             Falkland Islands  \
# 1993        0      NaN           ...                            0
# 1994        0      NaN           ...                            0
# 1995        0        5           ...                            0
# 1996        0        5           ...                            0
# 1997        0        3           ...                            0
# ...
