# %%
import pandas as pd

# %%
pros = pd.read_excel('Table49_0.xls')
pros.set_index('Action', inplace=True)
del pros.index.name
pros = pros.transpose()
pros.head()
# Out:
#       Total prosecutions  Total convictions  Total acquittals  \
# 1992               14655               9865                57
# 1993               18731              11685               240
# 1994               14854              10210                86
# 1995               17035              12075               124
# 1996               16115              12121               108
#
#       Total dismissals  Immigration prosecutions  Immigration convictions  \
# 1992              4733                     14138                     9766
# 1993              6806                     15566                    10189
# 1994              4558                     13068                     9180
# 1995              4836                     15337                    11110
# 1996              3886                     14223                    11014
#
#       Immigration acquittals  Immigration dismissals  \
# 1992                      57                    4315
# ...

# %%
pros.to_csv('../../Data/prosecutions.csv')
