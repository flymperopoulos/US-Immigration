# %%
import pandas as pd

# %%
act = pd.read_excel('Table60_1.xls')
act.set_index('Activities', inplace=True)
del act.index.name
act = act.transpose()
act.head()
# Out:
#       Total processed  Deportable aliens located  Mexican aliens  \
# 1992          1221904                    1199560         1168946
# 1993          1281721                    1263490         1230124
# 1994          1046576                    1031668          999890
# 1995          1336518                    1324202         1293508
# 1996          1561234                    1549876         1523141
#
#       Working in agriculture  \
# 1992                    5488
# 1993                    5393
# 1994                    5162
# 1995                    4487
# 1996                    2684
#
#       Working in trades, crafts, industry, and service  Seeking employment  \
# 1992                                              7165             1065159
# 1993                                              7403             1117414
# 1994                                              8068              901826
# 1995                                             12552             1185761
# ...

# %%
act.to_csv('../../Data/border_patrol.csv')
