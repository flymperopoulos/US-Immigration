# %%
import pandas as pd

# %%
nat13 = pd.read_excel('natzsuptable1d_4.xls')
nat12 = pd.read_excel('natzsuptable1d_3.xls')
nat11 = pd.read_excel('natzsuptable1d_2.xls')
nat10 = pd.read_excel('natzsuptable1d_1.xls')
nat09 = pd.read_excel('natzsuptable1d_0.xls')
nat08 = pd.read_excel('natzsuptable1d.xls')
nat07 = pd.read_excel('natzsuptable1dfy07.xls')
nat06 = pd.read_excel('NatzSupTable1DFY06.xls')
nat05 = pd.read_excel('NatzSupTable1fy05D.xls')
nat04 = pd.read_excel('NatzSupTable1fy04D.xls')

# %%
nat13.head()
# Out:
#                 Total  Alabama  Alaska  Arizona  Arkansas  California  \
# Total          779929     1811    1083    13165      1567      164792
# Africa          71872      224      73     1136        79        5763
# Asia           275700      844     550     3579       555       84764
# Europe          80333      200     177     1167       106       11455
# North America  271807      417     175     6780       749       55702
#
#                Colorado  Connecticut  Delaware  District of Columbia   ...     \
# Total              6263         9253      1460                  1854   ...
# Africa             1039          676       296                   657   ...
# Asia               1819         2493       559                   342   ...
# Europe             1013         2001       124                   237   ...
# North America      1932         2414       372                   454   ...
#
#                U.S. Armed Services Posts  U.S. Dependencies  Utah  Vermont  \
# ...

# %%
nat12.head()
# Out:
#                 Total  Alabama  Alaska  Arizona  Arkansas  California  \
# Total          757434     2084    1186    13090      1605      158850
# Africa          74775      243      70     1128        85        5491
# Asia           257035      882     680     3062       601       81444
# Europe          82714      209     220     1309       107       11241
# North America  261673      586     146     7115       741       53654
#
#                Colorado  Connecticut  Delaware  District of Columbia   ...     \
# Total              7726         8332      1456                  1958   ...
# Africa             1353          609       359                   743   ...
# Asia               2071         2158       485                   336   ...
# Europe             1284         1838       146                   242   ...
# North America      2537         1975       371                   457   ...
#
#                U.S. Armed Services Posts  U.S. Dependencies  Utah  Vermont  \
# ...

# %%
nat11.head()
# Out:
#                 Total  Alabama  Alaska  Arizona  Arkansas  California  \
# Total          694193     2439    1115    12784      1559      151183
# Africa          69738      324      58     1032        88        5686
# Asia           249940     1101     595     3156       547       78467
# Europe          82209      296     191     1377       113       10760
# North America  217750      553     175     6709       722       49466
#
#                Colorado  Connecticut  Delaware  District of Columbia   ...     \
# Total              7805         8370      1470                  1016   ...
# Africa             1131          660       345                   375   ...
# Asia               2133         2327       514                   189   ...
# Europe             1324         2014       152                   142   ...
# North America      2662         1840       362                   207   ...
#
#                U.S. Armed Services Posts  U.S. Territories  Utah  Vermont  \
# ...

# %%
nat10.head()
# Out:
#                 Total  Alabama  Alaska  Arizona  Arkansas  California  \
# Total          619913     2027     831    10340      1275      129354
# Africa          64023      202      67      942        64        5480
# Asia           251598     1037     395     3202       531       74328
# Europe          77951      232     173     1259       100        9987
# North America  163888      418     115     4500       537       33706
#
#                Colorado  Connecticut  Delaware  District of Columbia   ...     \
# Total              7165         7452      1829                  1319   ...
# Africa             1083          600       345                   485   ...
# Asia               2178         2371       810                   211   ...
# Europe             1299         1900       198                   210   ...
# North America      2107         1468       373                   289   ...
#
#                U.S. Armed Services Posts  U.S. Dependencies  Utah  Vermont  \
# ...

# %%
nat09.head()
# Out:
#                 Total  Alabama  Alaska  Arizona  Arkansas  California  \
# Total          743715     1775    1100    12377      1648      179754
# Africa          60383      185      44      741        67        5426
# Asia           276375      864     567     3619       608       86570
# Europe          90149      230     220     1346       119       12055
# North America  250266      391     178     6233       789       68323
#
#                Colorado  Connecticut  Delaware  District of Columbia   ...     \
# Total              6813        10421      1545                  2188   ...
# Africa              891          723       241                   620   ...
# Asia               2165         3194       703                   397   ...
# Europe             1217         2565       149                   294   ...
# North America      2115         2371       365                   633   ...
#
#                U.S. Armed Services Posts  U.S. Dependencies  Utah  Vermont  \
# ...

# %%
nat08.head()
# Out:
#                  Total  Alabama  Alaska  Arizona  Arkansas  California  \
# Total          1046539     1982    1145    24055      2330      297909
# Africa           54420      129      38      790        84        4968
# Asia            323792      934     586     4490       732      109898
# Europe          115187      266     192     2220       147       17573
# North America   462372      525     235    15777      1283      155006
#
#                Colorado  Connecticut  Delaware  District of Columbia   ...     \
# Total             11972         9589      1425                  1492   ...
# Africa              989          504       163                   379   ...
# Asia               3208         2667       600                   281   ...
# Europe             2077         2260       148                   159   ...
# North America      5032         2586       413                   509   ...
#
#                U.S. Armed Services Posts  U.S. Dependencies  Utah  Vermont  \
# ...

# %%
nat07.head()
# Out:
#                 Total  Alabama  Alaska  Arizona  Arkansas  California  \
# Total          660477     1343     849    12091      1214      181684
# Africa          41652      122      31      567        52        3855
# Asia           238797      617     419     2733       375       81705
# Europe          86742      179     165     1516        94       13265
# North America  241163      326     164     6831       631       76195
#
#                Colorado  Connecticut  Delaware  District of Columbia   ...     \
# Total              7829         4552      1094                  1334   ...
# Africa              784          268       149                   375   ...
# Asia               2245         1458       493                   249   ...
# Europe             1420         1186       113                   201   ...
# North America      2959         1048       267                   360   ...
#
#                U.S. Armed Services Posts  U.S. Dependencies  Utah  Vermont  \
# ...

# %%
nat06.head()
# Out:
#                 Total  Alabama  Alaska  Arizona  Arkansas  California  \
# Total          702589     1946     831     9707      1133      152836
# Africa          50397      156      26      528        55        4206
# Asia           257125      983     419     2437       391       77511
# Europe         107459      326     159     1595       106       13246
# North America  223086      341     150     4760       525       51584
#
#                Colorado  Connecticut  Delaware  District of Columbia   ...     \
# Total              5526         7231      1187                  1089   ...
# Africa              597          467       153                   315   ...
# Asia               1671         2138       492                   197   ...
# Europe             1212         1967       155                   175   ...
# North America      1754         1686       288                   292   ...
#
#                U.S. Armed Services Posts  U.S. Dependencies  Utah  Vermont  \
# ...

# %%
nat05.head()
# Out:
#                 Total  Alabama  Alaska  Arizona  Arkansas  California  \
# Total          604280      795     951     6785       990      170489
# Africa          38830       61      19      333        34        4456
# Asia           237724      405     503     1648       411       87978
# Europe          97482      132     163     1369       117       15318
# North America  180572      154     190     3188       375       55496
#
#                Colorado  Connecticut  Delaware  District of Columbia   ...     \
# Total              5681         8169       945                   939   ...
# Africa              608          473        95                   237   ...
# Asia               1767         2180       421                   192   ...
# Europe             1400         2377       114                   146   ...
# North America      1584         1987       263                   270   ...
#
#                Texas  Utah  Vermont  Virginia  Washington  West Virginia  \
# ...

# %%
nat04.head()
# Out:
#           Total  Alabama  Alaska  Arizona  Arkansas  California  Colorado  \
# Total    537151      734     777     6500       823      145594      6007
# Europe    89014       97     111     1206        84       14468      1521
# Albania    3324        0       0       10         0          33       NaN
# Armenia    1793        0     NaN        5         0        1537         4
# Austria     277      NaN       0        7       NaN          53         7
#
#          Connecticut  Delaware  District of Columbia   ...     \
# Total           5957       982                   882   ...
# Europe          1711       148                   126   ...
# Albania          176       NaN                     5   ...
# Armenia            9         0                   NaN   ...
# Austria            4         0                   NaN   ...
#
#          U.S. Armed Services Posts  U.S. Possessions  Utah  Vermont  Virginia  \
# Total                            2              1849  3110      419     13478
# ...

# %%
nat04.to_csv('../../Data/nat_reg_state04.csv')
nat05.to_csv('../../Data/nat_reg_state05.csv')
nat06.to_csv('../../Data/nat_reg_state06.csv')
nat07.to_csv('../../Data/nat_reg_state07.csv')
nat08.to_csv('../../Data/nat_reg_state08.csv')
nat09.to_csv('../../Data/nat_reg_state09.csv')
nat10.to_csv('../../Data/nat_reg_state10.csv')
nat11.to_csv('../../Data/nat_reg_state11.csv')
nat12.to_csv('../../Data/nat_reg_state12.csv')
nat13.to_csv('../../Data/nat_reg_state13.csv')
