# %%
import pandas as pd

# %%
imm = pd.read_excel('table01.xls')
imm.set_index('Year', inplace=True)
del imm.index.name
imm.head()

# %%
imm.to_csv('../../Data/immigration.csv')
# Out:
#       Immigrants
# 1820        8385
# 1821        9127
# 1822        6911
# 1823        6354
# 1824        7912

# %%
imm = pd.read_excel('table02.xls')
imm.set_index('Region', inplace=True)
del imm.index.name
imm = imm.transpose()
imm.head()
imm.loc[[ind for ind in imm.index if type(ind)==int]]
# Out:
#         Total  Europe  Austria-Hungary  Austria  Hungary   Belgium  \
# 1820     8385    7690              NaN      NaN       NaN        1
# 1994   804416  166279             2123     1314       809      621
# 1995   720461  132914             2190     1340       850      694
# 1996   915900  151898             2325     1182      1143      802
# 1997   798378  122358             1964     1044       920      633
# 1998   654451   92911             1435      610       825      557
# 1999   646568   94373             1518      727       791      522
# 2000   849807  133362             2024      997      1027      827
# 2001  1064318  177833             2318     1004      1314     1002
# 2002  1063732  177652             4016     2657      1359      842
# 2003   705827  102843             2181     1163      1018      518
#
#       Czechoslovakia   Denmark  France  Germany   ...     \
# 1820              NaN       20     371      968   ...
# ...

# %%
imm.to_csv('../../Data/immigration_reg.csv')
