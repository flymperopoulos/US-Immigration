# %%
import pandas as pd

# %%
nat = pd.read_excel('table20_5.xls', index_col=[0])
del nat.index.name
nat.head()
# Out:
#       Petitions filed  Total naturalized  Civilians naturalized  \
# 1907            21113               7941                   7941
# 1908            44032              25975                  25975
# 1909            43141              38374                  38374
# 1910            55750              39448                  39448
# 1911            74740              56683                  56683
#
#       Military naturalized  Unreported naturalized  Petitions denied
# 1907                   NaN                       0               250
# 1908                   NaN                       0              3330
# 1909                   NaN                       0              6341
# 1910                   NaN                       0              7781
# 1911                   NaN                       0              9017

# %%
nat.to_csv('../../Data/naturalization.csv')

# %%
nate = pd.read_excel('Table32_0.xls', index_col=[0])
natl = pd.read_excel('table21d_5.xls', index_Col=[0])

# %%
natl
# Out:
#                             2004    2005    2006    2007     2008    2009  \
# Total                     537151  604280  702589  660477  1046539  743715
# Africa                     34531   38830   50397   41652    54418   60383
# Asia                      224072  243514  263516  243783   330361  276375
# Europe                     83961   91745  101125   81788   108688   90214
# North America             151008  180525  223034  241136   462312  250209
# Oceania                     3551    3898    3657    3342     4781    3928
# South America              38670   44498   59980   48128    84845   61666
# Afghanistan                 1323    1464    2018    2013     2650    2588
# Albania                     3324    3830    3964    2786     2972    3483
# Algeria                      616     722     825     578      894    1024
# American Samoa               137     294     247     161      178     265
# Angola                        87      86     106     105      161      95
# ...

# %%
nate = nate.ix[0:-1]

# %%
dic = {}
for val in natl.index:
    if val in dic.iterkeys():
        dic[val] += 1
    else:
        dic[val] = 1
        
for key, val, in dic.iteritems():
    if val > 1:
        print key, val
        
for i, val in enumerate(natl.index):
    if val == 'Total':
        print i
# Out:
# 0

# %%
nat_reg = pd.concat([nate, natl], axis=1)
nat_reg = nat_reg.transpose()

# %%
nat_reg
# Out:
#       Afghanistan  Africa  Albania  Algeria  American Samoa  Andorra  Angola  \
# 1991         1394   10468       72      116              47      NaN      33
# 1992         1052    9731       92      103              47      NaN      39
# 1993         1548   11539       88      126              71        0      59
# 1994         1995   16073      109      183             103        0      98
# 1995         2031   18495      103      188             122        0      68
# 1996         4141   26970      348      275             148      NaN     122
# 1997         1839   15996      419      173              38        0      91
# 1998         1736   12467      351      143              63      NaN      73
# 1999         2752   20401      599      277              75        3      99
# 2000         2843   25850      826      427              80      NaN     113
# 2001         1947   24312     1032      469              97      NaN      86
# ...

# %%
nat_reg.to_csv('../../Data/naturalization_reg.csv')

# %%
nat_state = pd.read_excel('Table33D.xls', inde_col=[0])
nat_state = nat_state.transpose()

# %%
nat_state
# Out:
#         Total  Alabama  Alaska  Arizona  Arkansas  California  Colorado  \
# 1986   280623      664     577     3121       605      105284      2490
# 1987   227008      506     509     2788       540       82607      1878
# 1988   242063      646     622     2136       417       65397      2252
# 1989   233777      653     490     2562       374       50286      2535
# 1990   270101      590     607     2152       388       61736      1414
# 1991   308058      798     463     2090       413      125661      2004
# 1992   240252      598     793     3037       380       52411      1402
# 1993   314681      719     530     2548       405       68100      2732
# 1994   434107      954     648     3894       615      118567      3171
# 1995   488088      860     675     4059       163      171285      3753
# 1996  1044689     1002       4     6838         6      378014      5168
# 1997   598225      644     757     3767       809      187432      3560
# ...

# %%
nat_state.to_csv('../../Data/naturalization_state.csv')
