# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# plt.rcParams['figure.figsize'] = (10.0, 8.0)

def import_data():
    '''Import all data from csv files'''
    global border_patrol, investigations, apprehended, immigration
    global lpr, naturalization, prosecutions, refugees, removed, immig_reg
    border_patrol = pd.read_csv('DHS_Data/border_patrol.csv', index_col=0)
    investigations = pd.read_csv('DHS_Data/investigations.csv', index_col=0)
    apprehended = pd.read_csv('DHS_Data/apprehended.csv', index_col=0)
    immigration = pd.read_csv('DHS_Data/immigration.csv', index_col=0)
    lpr = pd.read_csv('DHS_Data/lpr.csv', index_col=0)
    naturalization = pd.read_csv('DHS_Data/naturalization.csv', index_col=0)
    prosecutions = pd.read_csv('DHS_Data/prosecutions.csv', index_col=0)
    refugees = pd.read_csv('DHS_Data/refugee.csv', index_col=0)
    removed = pd.read_csv('DHS_Data/removed.csv', index_col=0)
    immig_reg = pd.read_csv('DHS_Data/immigration_reg.csv', index_col=0)
    
import_data()

# %%
count = lpr.loc[1993::].describe().loc['count']
mean = lpr.loc[1993::].describe().loc['mean']

# print count*mean
# print lpr.loc[2013]
# print lpr.loc[2013]/(count*mean)

# lpr.plot()
lpr.loc[1980::].plot()
plt.xlabel('Year')
plt.ylabel('People')
plt.title('Immigration to the U.S.')
plt.savefig('final-graphs/lpr.png')

# %%
# immigration['Immigrants'][1:].plot()
# naturalization[['Petitions filed', 'Total naturalized', 'Petitions denied']].plot()
a = naturalization[['Petitions filed', 'Total naturalized', 'Petitions denied']].loc[1990:2013]
plt.xlabel('Year')
plt.ylabel('People')
plt.title('Naturalizations')
plt.savefig('final-graphs/naturalizations.png')
a.to_csv('nat_data.csv')
a
# Out:
#       Petitions filed  Total naturalized  Petitions denied
# 1990           233843             267586              6516
# 1991           206668             307394              6268
# 1992           342238             239664             19293
# 1993           521866             313590             39931
# 1994           543353             429123             40561
# 1995           959963             485720             46067
# 1996          1277403            1040991            229842
# 1997          1412712             596010            130676
# 1998           932957             461169            137395
# 1999           765346             837418            379993
# 2000           460916             886026            399670
# 2001           501643             606259            218326
# 2002           700649             572646            139779
# 2003           523370             462435             91599
# 2004           662796             537151            103339
# 2005           602972             604280            108247
# 2006           730642             702589            120722
# 2007          1382993             660477             89683
# 2008           525786            1046539            121283
# 2009           570442             743715            109813
# 2010           710544             619913             56994
# 2011           756008             694193             57065
# 2012           899162             757434             65874
# 2013           772623             779929             83112

# %%
df = pd.concat([lpr, refugees, apprehended], axis=1)
df[160:].plot()
df = df[160:]
# df.plot(x='Aliens Apprehended', y='LPR', style='o')
df = df[['Aliens Apprehended', 'LPR']]
# print df.corr()
# print df.index
# print 'Note: The "immigration" dataset becomes the "obtained legal permanent resident status" dataset'
# removed.plot()
# print 'Removals have only begun growing as we reach the 21st Century'
# plt.xlabel('Year')
# plt.ylabel('People')
plt.title
df.to_csv('compare_dhs_data.csv')

# %%
removed.dropna()
print removed.index
removed.plot()
removed.loc['1980':'2005'].plot()
# Out:
# Index([u'1961', u'1962', u'1963', u'1964', u'1965', u'1966', u'1967', u'1968',
#        u'1969', u'1970', u'1971', u'1972', u'1973', u'1974', u'1975', u'1976',
#        u'1977', u'1978', u'1979', u'1980', u'1981', u'1982', u'1983', u'1984',
#        u'1985', u'1986', u'1987', u'1988', u'1989', u'1990', u'1991', u'1992',
#        u'1993', u'1994', u'1995', u'1996', u'1997', u'1998'],
#       dtype='object')

# %%
border_patrol.dropna()
border_patrol[['Deportable aliens located', 'Seeking employment']].plot()
border_patrol.columns
# Out:
# Index([u'Total processed', u'Deportable aliens located', u'Mexican aliens',
#        u'Working in agriculture',
#        u'Working in trades, crafts, industry, and service',
#        u'Seeking employment', u'Canadian aliens', u'Other aliens',
#        u'Smugglers of aliens located', u'Aliens located who were smuggled ',
#        u'Seizures (conveyances)', u'Total value', u'Narcotics value',
#        u'Other seizures value'],
#       dtype='object')

# %%
investigations.dropna()
# Out:
#       Criminal cases  Criminal prosecutions  Criminal convictions  \
# 1996         54065.0                 1468.0                1254.0
# 1997         74612.0                 1436.0                1166.0
# 1998         87093.0                 2195.0                1704.0
# 1999        100044.0                 2754.0                2409.0
# 2000         90519.0                 3802.0                3022.0
# 2001         89222.0                 2962.0                2253.0
#
#       Employer cases  Employer warnings  Employer notice of Intent to Fine  \
# 1996          5149.0              668.0                             1019.0
# 1997          7537.0              733.0                              862.0
# 1998          7788.0              642.0                             1023.0
# 1999          3898.0              383.0                              417.0
# 2000          1966.0              282.0                              178.0
# 2001          1595.0              169.0                              100.0
#
#       Employer final orders  Employer arrests  Fraud cases  \
# 1996                  808.0           14164.0       4369.0
# 1997                  777.0           17552.0       4843.0
# 1998                  535.0           13914.0       4613.0
# 1999                  297.0            2849.0       4300.0
# 2000                  180.0             953.0       3733.0
# 2001                   78.0             418.0       3721.0
#
#       Fraud prosecutions  Fraud convictions  Smuggling cases  \
# 1996               613.0              339.0           2643.0
# 1997               332.0              190.0           1171.0
# 1998               447.0              310.0           2033.0
# 1999               509.0              338.0           2043.0
# 2000               483.0              259.0           3309.0
# 2001               397.0              214.0           2885.0
#
#       Smugglers arrested  Smuggled aliens arrested  Smuggling prosecutions    \
# 1996              4699.0                   43243.0                    3360.0
# 1997              3381.0                   35084.0                    2287.0
# 1998              2812.0                   45128.0                    1830.0
# 1999              4253.0                   41364.0                    1951.0
# 2000              4139.0                   46001.0                    2618.0
# 2001              3139.0                   32429.0                    2124.0
#
#       Smuggling convictions  Inspection violation cases  \
# 1996                 2838.0                     33138.0
# 1997                 1737.0                     33910.0
# 1998                 1183.0                     25407.0
# 1999                 1199.0                     27085.0
# 2000                 1474.0                     38311.0
# 2001                 1174.0                     25301.0
#
#       Inspection violation arrests
# 1996                            15365.0
# 1997                            13702.0
# 1998                            11337.0
# 1999                            13879.0
# 2000                            14963.0
# 2001                            11162.0

# %%
# prosecutions[['Fines (dollars)']].plot()
prosecutions['Imprisonment (years)'].plot()
plt.xlabel("Year")
plt.ylabel("Years Sentenced")
plt.title("Total Imprisonment Sentenced")
plt.savefig('final-graphs/imprisonment.png')

# %%
prosecutions.dropna()
print prosecutions.columns
prosecutions[['Total prosecutions', 'Total convictions',]].plot()
prosecutions.index.name = 'Year'
d3_import = prosecutions['Total prosecutions']
d3_import.name = 'Prosecutions'
print d3_import
d3_import.to_csv('d3_import.csv', header=True)
# Out:
# Index([u'Total prosecutions', u'Total convictions', u'Total acquittals',
#        u'Total dismissals', u'Immigration prosecutions',
#        u'Immigration convictions', u'Immigration acquittals',
#        u'Immigration dismissals', u'Naturalization prosecutions',
#        u'Naturalization convictions', u'Naturalization acquittals',
#        u'Naturalization dismissals', u'Other prosecutions',
#        u'Other convictions', u'Other acquittals', u'Other dismissals',
#        u'Fines (dollars)', u'Immigration fines', u'Naturalization fines',
#        u'Other fines', u'Imprisonment (years)', u'Immigration imprisonment',
#        u'Naturalization violations', u'Other violations'],
#       dtype='object')
# Year
# 1992    14655.0
# 1993    18731.0
# 1994    14854.0
# 1995    17035.0
# 1996    16115.0
# 1997    19180.0
# 1998    23826.0
# 1999    22491.0
# 2000    22926.0
# 2001    24316.0
# 2002    23850.0
# 2003    24918.0
# 2004    19541.0
# Name: Prosecutions, dtype: float64

# %%
prosecutions[['Immigration prosecutions', 'Naturalization prosecutions', 'Other prosecutions']].plot()
investigations.describe().plot.bar()

# %%
import_data()

removed.dropna(inplace=True)
inds = [str(x) for x in prosecutions.index.tolist()]
prosecutions.index = inds
actions = pd.concat([prosecutions['Total prosecutions'], removed['Returns'].loc['1992'::]], axis=1)

removed[['Returns', 'Removals', 'Formal removals']].plot()

fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
# print actions

actions['Total prosecutions'].plot(ax=ax1, colormap='inferno')
actions['Returns'].plot(ax=ax2)

ax1.set_xlabel('Year')
ax1.set_ylabel('Prosecutions', color='k')
ax2.set_ylabel('Deportations', color='b')

# %% [markdown]
# #### 1950: Beginning of red scare leads to rise in returns
# #### 1980: Sharp drop in returns after consistent rise
# #### 1985: Sharp rise in retuns
# #### 1996: Peak in naturalizations and in aliens apprehended, barely in LPR, sharp rise in convictions, drop in acquittals, rise in prosecutions. Literally everything gets worse here
# #### 2001: Apprehended value drops because of 9/11? Drop in returns and apprehensions as well. Or focusing less resources
# #### 2002: Drop in acquittals even more
# #### 2005: Rise in LPR, precedes spike in naturalizations

# %%
import_data()

print immig_reg['Europe'].index
immig_reg['Europe'].plot
# Out:
# Index([u'1820', u'1821-30', u'1831-40', u'1841-50', u'1851-60', u'1861-70',
#        u'1871-80', u'1881-90', u'1891-1900', u'1901-10', u'1911-20',
#        u'1921-30', u'1931-40', u'1941-50', u'1951-60', u'1961-70', u'1971-80',
#        u'1981-90', u'1991-93', u'1991-94', u'1991-95', u'1994', u'1995',
#        u'1996', u'1997', u'1998', u'1999', u'1991-99', u'2000', u'1991-2000',
#        u'2001', u'2002', u'2003', u'1820-1998', u'1820-1999', u'1820-2000',
#        u'1820-2001', u'1820-2002', u'1820-2003'],
#       dtype='object')
