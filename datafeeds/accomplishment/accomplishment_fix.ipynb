# %%
import pandas as pd

# %%
acc = pd.read_excel('accomplishmentsINS92-01.xls')
acc.set_index('Accomplishment', inplace=True)
del acc.index.name
acc = acc.transpose()
# acc.to_csv('../../Data/accomplishments.csv')

# %%
acc.head()
# Out:
#       Criminal Cases  Criminal Prosecutions  Criminal Convictions  \
# 1992           38716                   2027                  1688
# 1993           45291                   2041                  1954
# 1994           46236                   2386                  2172
# 1995           45619                   1965                  1590
# 1996           54065                   1468                  1254
#
#       Employer Cases  Employer Warnings  Employer Notice of Intent to Fine  \
# 1992            7053                840                               1461
# 1993            6237                758                               1302
# 1994            6169                683                               1063
# 1995            5283                550                               1055
# 1996            5149                668                               1019
#
#       Employer Final orders  Employer Arrests  Fraud Cases  \
# ...
