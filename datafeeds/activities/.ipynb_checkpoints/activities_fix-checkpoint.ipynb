# %%
import pandas as pd

# %%
act = pd.read_excel('activities92-01.xls')
act.set_index('Activities and accomplishments', inplace=True)
del act.index.name
act = act.transpose()
act.to_csv('../../Data/activities.csv')

# %%
act.head()
# Out:
#       Processed  Total Located  Mexican aliens located  \
# 1992    1221904        1199560                 1168946
# 1993    1281721        1263490                 1230124
# 1994    1046576        1031668                  999890
# 1995    1336518        1324202                 1293508
# 1996    1561234        1549876                 1523141
#
#       Mexican Aliens working in agriculture located  \
# 1992                                           5488
# 1993                                           5393
# 1994                                           5162
# 1995                                           4487
# 1996                                           2684
#
#       Mexican aliens working in trades located  \
# 1992                                      7165
# 1993                                      7403
# 1994                                      8068
# 1995                                     12552
# 1996                                      9413
#
# ...
