# %%
import pandas as pd

# %%
conv = pd.read_excel('convictions93-04.xls')
conv.set_index('Violations',1, inplace=True)
del conv.index.name

# %%
conv = conv.transpose()
conv
# Out:
#                                                     1992   1993   1994   1995  \
# Total                                               9865  11685  10210  12075
# Immigration violations                              9766  10189   9180  11110
# Entry of aliens illegally                           6341   7187   6610   7446
# Reentry of deported aliens                           477    767    803   1475
# Bringing in, transporting, harboring illegal al...   977   1008    731    758
# Fraud and false statements to obtain or confer ...   109     72     28     39
# Fraud, forgery, misuse of visas, alien registra...   306    383    353    301
# Fraud, forgery, misuse of identification documents   497    688    638   1032
# Conspiring to defraud the United States              121     37      6      6
# Employing unauthorized aliens, peonage, false a...   NaN     40     11     52
# Other immigration violations                         401      7      0    NaN
# ...

# %%
conv.to_csv('../Data/conviction.csv')
