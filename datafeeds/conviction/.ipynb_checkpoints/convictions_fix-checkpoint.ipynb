# %%
import pandas as pd

# %%
conv = pd.read_excel('Table50.xls')
conv.set_index('Violations', inplace=True)
del conv.index.name
conv = conv.transpose()
conv.head()
# Out:
#       All violations  Immigration violations  Entry of aliens illegally  \
# 1992            9865                    9766                       6341
# 1993           11685                   10189                       7187
# 1994           10210                    9180                       6610
# 1995           12075                   11110                       7446
# 1996           12121                   11014                       6361
#
#       Reentry of deported aliens  \
# 1992                         477
# 1993                         767
# 1994                         803
# 1995                        1475
# 1996                        2331
#
#       Bringing in, transporting, harboring illegal aliens  \
# 1992                                                977
# 1993                                               1008
# 1994                                                731
# 1995                                                758
# ...

# %%
conv.to_csv('../../Data/conviction.csv')
