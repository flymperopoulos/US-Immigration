# %%
import pandas as pd

# %%
app = pd.read_excel('table33_5.xls')
app.set_index('Year', inplace=True)
del app.index.name
app.head()
# Out:
#       Aliens Apprehended
# 1925               22199
# 1926               12735
# 1927               16393
# 1928               23566
# 1929               32711

# %%
app.to_csv('../../Data/apprehended.csv')

# %%
app = pd.read_excel('table34d_5.xls')
app.set_index('Region', inplace=True)
del app.index.name
app = app.transpose()
app.head()
# Out:
#         Total  Africa   Asia  Europe  North America  Oceania  South America  \
# 2004  1264232    2092   7229    2826        1214322      284          14093
# 2005  1291065    2804   9273    2926        1237532      175          38128
# 2006  1206412    3544  10342    3025        1179600      221           9002
# 2007   960772    3085   7348    2466         938932      202           8671
# 2008  1043799    5218  13201    5150        1003176      506          15526
#
#       Unknown  Afghanistan  Albania  ...    United Arab Emirates  \
# 2004    23386           57      163  ...                       9
# 2005      227           55      253  ...                       6
# 2006      678           53      350  ...                      35
# 2007       68           28      259  ...                       8
# 2008     1022           74      362  ...                       4
#
#       United Kingdom  Uruguay  Uzbekistan  Venezuela  Vietnam  Yemen  Zambia  \
# ...

# %%
app.to_csv('../../Data/apprehended_reg.csv')
