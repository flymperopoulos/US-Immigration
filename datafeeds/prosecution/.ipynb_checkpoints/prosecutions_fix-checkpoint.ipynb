# %%
import pandas as pd

# %%
pros = pd.read_excel('Table49_0.xls')
pros.set_index('Action', inplace=True)
del pros.index.name
pros.head()

# %%
pros.to_csv('../../Data/prosecutions.csv')
# Out:
#                                 1992     1993       1994    1995     1996  \
# Total prosecutions             14655    18731      14854   17035    16115
# Total convictions               9865    11685      10210   12075    12121
# Total acquittals                  57      240         86     124      108
# Total dismissals                4733     6806       4558    4836     3886
# Immigration prosecutions       14138    15566      13068   15337    14223
# Immigration convictions         9766    10189       9180   11110    11014
# Immigration acquittals            57      145         74      94      107
# Immigration dismissals          4315     5232       3814    4133     3102
# Naturalization prosecutions      517      695        506     328      176
# Naturalization convictions        99      287        160     113      133
# Naturalization acquittals          0       82         10       5        0
# Naturalization dismissals        418      326        336     210       43
# ...
