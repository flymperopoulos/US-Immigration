# %%
import pandas as pd

# %%
lpr = pd.read_excel('lpr1820-13.xls')
lpr.set_index('Year', inplace=True)
del lpr.index.name
lpr.to_csv('../../Data/lpr.csv')

# %%
lpr.head()
# Out:
#       Obtained LPR
# 1820          8385
# 1821          9127
# 1822          6911
# 1823          6354
# 1824          7912

# %%
lpr_reg = pd.read_excel('lpr_reg1820-14.xls')
lpr_reg.head()
lpr_reg.set_index('Country', inplace=True)
del lpr_reg.index.name
lpr_reg = lpr_reg.transpose()
lpr_reg.to_csv('../lpr_reg.csv')

# %%
lpr_reg
# Out:
#                  Total   Europe   Austria-Hungary  Austria  Hungary  Belgium  \
# 1820 to 1829    128502    99618                 0        0        0       28
# 1830 to 1839    538381   422853                 0        0        0       20
# 1840 to 1849   1427337  1369423                 0        0        0     3996
# 1850 to 1859   2814554  2622617                 0        0        0     5765
# 1860 to 1869   2081261  1880389              3375     2700      483     5785
# 1870 to 1879   2742137  2252050             60127    54529     5598     6991
# 1880 to 1889   5248568  4638684            314787   204805   109982    18738
# 1890 to 1899   3694294  3576411            534059   268218   203350    19642
# 1900 to 1909   8202388  7572569           2001376   532416   685567    37429
# 1910 to 1919   6347380  4985411           1154727   589174   565553    32574
# 1920 to 1929   4295510  2560340             60891    31392    29499    21511
# ...
