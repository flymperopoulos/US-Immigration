# %%
import pandas as pd

# %%
remov = pd.read_excel('table39_3.xls')
remov.set_index('Year', 1, inplace=True)
del remov.index.name
remov.head()
# Out:
#             Removals  Returns  Formal removals  Voluntary departures
# 1892-1900        NaN      NaN            25642                   NaN
# 1901-10          NaN      NaN           119769                   NaN
# 1911-20          NaN      NaN           206021                   NaN
# 1921-30          NaN      NaN           281464                 72233
# 1931-40          NaN      NaN           185303                 93330

# %%
remov.to_csv('../../Data/removed.csv')
# Out:
#       Removals  Returns
# 1892      2801      NaN
# 1893      1630      NaN
# 1894      1806      NaN
# 1895      2596      NaN
# 1896      3037      NaN

# %%
remove = pd.read_excel('Table43D.xls', index_col=[0,1])
remove.index.names = (None, None)

# %%
remove.loc[1993:1998]
# Out:
#                     Total  Europe  Albania  Andorra  Armenia  Austria  \
# 1993 Total          42540     781        3        0        0        5
#      Criminal       29457     334      NaN        0        0      NaN
#      Non-criminal   13083     447      NaN        0        0      NaN
# 1994 Total          45664     929       15        0        3      NaN
#      Criminal       32510     384        4        0      NaN      NaN
#      Non-criminal   13154     545       11        0      NaN      NaN
# 1995 Total          50924     934       11      NaN        7        3
#      Criminal       33842     402        4        0      NaN      NaN
#      Non-criminal   17082     532        7      NaN      NaN      NaN
# 1996 Total          69680    1056       13        0       10       10
#      Criminal       38015     458        5        0      NaN      NaN
#      Non-criminal   31665     598        8        0      NaN      NaN
# ...

# %%
removl = pd.read_excel('table37d_1.xls', index_col=[0,1])

# %%
removl.head()
# Out:
#                     Total  Africa  Asia  Caribbean  Central America  Europe  \
# 1999  Total        183114    1555  3334       6534            12414    2184
#      Criminal       71188     620  1015       4613             5063     924
#      Non-criminal  111926     935  2319       1921             7351    1260
# 2000  Total        188467    1593  3725       6706            15212    2588
#      Criminal       73065     623  1021       4609             5391     968
#
#                    North America  Oceania  South America  Afghanistan  \
# 1999  Total               151461      186           5423           31
#      Criminal              56451      104           2392           20
#      Non-criminal          95010       82           3031           11
# 2000  Total               152414      243           5940            7
#      Criminal              58056      128           2264            3
#
#                     ...     United Kingdom  Uruguay  Uzbekistan  Venezuela  \
# ...

# %%
removals = pd.concat([remove.loc[1993:1998], removl])
removals.index[12]
# Out:
# (1997, u'Total')

# %%
removals.to_csv('../../Data/removals_reg.csv')

# %%
removals_current = pd.read_excel('table40d_1.xls', index_col=[0])
